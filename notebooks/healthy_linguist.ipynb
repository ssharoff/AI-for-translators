# %%
name = 'Your name'
age = 24

# %%
# Maximum heart rate
maxHR = 220 - age

# %%
# low range
low = maxHR * 0.7
# high range
high = maxHR * 0.85

# %%
print(f'{name}, a {age} yr. old linguist,')
print('should exercise for 30 minutes')
print(f'with a heartrate between ({low}, {high})')
